# %% [markdown]
# # Tads e Listas

# %% [markdown]
# **Q4** Implemente um TAD para representar uma lista encadeada circular (simplesmente encadeada) capaz de armazenar valores inteiros. Esse TAD deverá conter funções para:

# %%
class Node:
    def __init__(self, value=None):
        self.info = value
        self.next = None

    def __del__(self):
        print ("deleted")
    
class List:
    def __init__(self):
        self.node_head = None    
        
    def setNode(self, node):
        if self.node_head == None:
            node.next = node
            self.node_head = node
            
        else:
            ant = None
            itr = self.node_head
            while not(itr is self.node_head):
                ant = itr
                itr = itr.next
            if ant is None:
                #ant = self.node_head
                self.node_head.next = node
                node.next = self.node_head
            else:
                itr.next = node
                node.next = self.node_head
                #node.next = aux
                
            #self.node_head = node
            
            #ant.prox = node
            #node.prox = self.node_head
            #self.node_head = node
            
    def print_w(self):
        itr = self.node_head

        while True:
            print(itr.info)
            itr = itr.next
            if(itr is self.node_head):
                break
            
    #def print_w(self):
#        itr = self.node_head
#        if itr.next is self.node_head:
#            print(itr.info)
#            return
#        while not(itr.next is self.node_head):
#            print(itr.info)
#            itr = itr.next
                
    def print_list(self, node):
        if not(node is None):
            print(node.info)
            self.print_list(node.next)
            
    def is_empty(self):
        print(self.node_head)
        if self.node_head is None:
            return 1
        return 0    
    
    def find(self, value, node):
        if node is None:
            print("nó invalido ou não encontrado")
            return None
        else:
            if node.info is value:
                return value
            elif not(node.next is None):
                return self.find(value, node.next)
            else:
                print("não encontrado")
                return None
    
    def remove_rec(self, value, node, pre=None):
        if node is None:
            print("nó invalido ou não encontrado")
            return None
        else:
            if node.info is value:
                #return value
                if pre is None:
                    self.node_head = node.next
                elif node.next is None:
                    pre.next = None
                else:
                    pre.next = node.next
                return    
            if not(node.next is None):
                self.remove_rec(value, node.next, node)
            else:
                print("não encontrado")
                
    
    def remove(self, value):
        node = self.node_head
        if node is None:
            print("nó invalido ou não encontrado")
            return None
        else:
            pre = None
            while not(node is None):
                if node.info is value:
                    if pre is None:
                        self.node_head = node.next
                    elif node.next is Nonde:
                        pre.next = None
                    else:
                        pre.next = node.next
                else:
                    if node.next is None:
                        print("Não encontrado")
                        return
                    else:
                        pre = node
                        node = node.next
                    
    def free_list(self, node):
        if node is None:
            print("nó invalido")
            return None
        else:
            if not(node.next is None):
                self.free_list(node.next)
            del node

# %% [markdown]
# - Criar uma lista vazia

# %%
my_list = List()
print(my_list)
# Out:
# <__main__.List object at 0x0000021657215EF0>

# %% [markdown]
# - Inserir elemento no início;

# %%
my_list1 = List()
node1 = Node(2)
node2 = Node(1)
node3 = Node(3)
my_list1.setNode(node1)
my_list1.setNode(node2)
my_list1.setNode(node3)

print(my_list1.node_head)
# Out:
# deleted
# <__main__.Node object at 0x00000216573C4D68>

# %% [markdown]
# - Imprimir os valores armazenados na lista usando recursão

# %%
my_list1.print_w()
# Out:
# 2

# %% [markdown]
# - Imprimir os valores armazenados na lista usando recursão

# %%
my_list1.print_list(my_list1.node_head)
# Out:
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-5-89da8d8f5260> in <module>
# ----> 1 my_list1.print_list(my_list1.node_head)
#
# <ipython-input-1-06e562a37bbc> in print_list(self, node)
#      49         if not(node is None):
#      50             print(node.info)
# ---> 51             self.print_list(node.next)
#      52
#      53     def is_empty(self):
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-1-06e562a37bbc> in print_list(self, node)
#      49         if not(node is None):
#      50             print(node.info)
# ---> 51             self.print_list(node.next)
#      52
#      53     def is_empty(self):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# - Verificar se a lista está vazia (retorna 1 se vazia ou 0 se não vazia)

# %%
print(my_list.is_empty())
print(my_list1.is_empty())
# Out:
# None
# 1
# <__main__.Node object at 0x0000018A0DEC9AC8>
# 0

# %% [markdown]
# - Recuperar/Buscar um determinado elemento da lista

# %%
n3 = Node(3)
my_list1.setNode(n3)
print(my_list1.find(1,  my_list1.node_head))
print(my_list1.find(77, my_list1.node_head))
# Out:
# 1
# não encontrado
# None

# %% [markdown]
# - Remover um determinado elemento da lista

# %%
my_list2 = List()
no1 = Node(3)
my_list2.setNode(no1)
no2 = Node(2)
my_list2.setNode(no2)
my_list2.print_list(my_list2.node_head)
my_list2.remove(2)
print("removido")
my_list2.print_list(my_list2.node_head)

# %% [markdown]
# - Remover um determinado elemento da lista usando recursão

# %%
n4 = Node(4)
my_list1.setInitNode(n4)
n5 = Node(5)
my_list1.setInitNode(n5)
my_list1.print_list(my_list1.node_head)

# %%
my_list1.remove(5, my_list1.node_head)
print("removido o primeiro")
my_list1.print_list(my_list1.node_head)
my_list1.remove(2, my_list1.node_head)
print("removido o utimo")
my_list1.print_list(my_list1.node_head)
my_list1.remove(3, my_list1.node_head)
print("removido o meio")
my_list1.print_list(my_list1.node_head)

# %% [markdown]
# - Liberar a lista

# %%
my_list1.free_list(my_list1.node_head)
my_list1.print_list(my_list1.node_head)
